# %% [markdown]
# # CycleGan Photo to Monet

# %% [markdown]
# ## Imports

# %%
import re
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from tensorflow.keras.layers import Layer

from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# 2022-06-01 14:55:16.060677: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2022-06-01 14:55:16.060805: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Connecting to TPU

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

AUTOTUNE = tf.data.experimental.AUTOTUNE
    
print(tf.__version__)
# Out:
# Device: grpc://10.0.0.2:8470
# 2022-06-01 14:55:21.754731: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-01 14:55:21.758202: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2022-06-01 14:55:21.758238: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-01 14:55:21.758265: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (7a1243d5554f): /proc/driver/nvidia/version does not exist
# 2022-06-01 14:55:21.761786: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-01 14:55:21.763614: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-01 14:55:21.770717: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-01 14:55:21.799201: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-06-01 14:55:21.799264: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2022-06-01 14:55:21.823539: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-06-01 14:55:21.823591: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2022-06-01 14:55:21.825150: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30019
# Number of replicas: 8
# 2.4.1

# %% [markdown]
# ## Loading and Preprocessing Data

# %%
GCS_PATH = KaggleDatasets().get_gcs_path()
EPOCHS = 100
SIZE = 256
SIZE_RESIZE = 128
BATCH_SIZE = 16

# %%
MONET_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/monet_tfrec/*.tfrec'))
print('Monet TFRecord Files:', len(MONET_FILENAMES))

PHOTO_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/photo_tfrec/*.tfrec'))
print('Photo TFRecord Files:', len(PHOTO_FILENAMES))
# Out:
# Monet TFRecord Files: 5
# Photo TFRecord Files: 20
# 2022-06-01 14:55:27.904817: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2022-06-01 14:55:27.981016: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.

# %%
def random_crop(image):
    cropped_image = tf.image.random_crop(image, size=[SIZE_RESIZE, SIZE_RESIZE, 3])

    return cropped_image

# %%
def data_augment(image):
    p_spatial = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
    if p_rotate > .8:
        image = tf.image.rot90(image, k=3) 
    elif p_rotate > .6:
        image = tf.image.rot90(image, k=2) 
    elif p_rotate > .4:
        image = tf.image.rot90(image, k=1)
        
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    image = tf.image.random_crop(image, size=[SIZE_RESIZE, SIZE_RESIZE, 3])
        
    return image

# %%
IMAGE_SIZE = [SIZE, SIZE]

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = (tf.cast(image, tf.float32) / 127.5) - 1
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    
    return image

# %%
def load_dataset(filenames, apply_jitter=False, repeat=True, shuffle=True, batch_size=BATCH_SIZE):
    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
    
    if apply_jitter:
        dataset = dataset.map(data_augment, num_parallel_calls=AUTOTUNE)
            
    if repeat:
        dataset = dataset.repeat()
    if shuffle:
        dataset = dataset.shuffle(512)
        
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTOTUNE)
    
    return dataset

# %%
def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

n_monet_samples = count_data_items(MONET_FILENAMES)
n_photo_samples = count_data_items(PHOTO_FILENAMES)

# %%
monet_ds = load_dataset(MONET_FILENAMES, apply_jitter=True)
photo_ds = load_dataset(PHOTO_FILENAMES, apply_jitter=True)

photo_ds_test = load_dataset(PHOTO_FILENAMES, repeat=False, shuffle=False, batch_size=1)

# %%
example_monet = next(iter(monet_ds))
example_photo = next(iter(photo_ds))

# %%
plt.subplot(121)
plt.title('Photo')
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Monet')
plt.imshow(example_monet[0] * 0.5 + 0.5)

# %% [markdown]
# ## Diff Augmentation

# %%
def DiffAugment(x, policy='', channels_first=False):
    if policy:
        if channels_first:
            x = tf.transpose(x, [0, 2, 3, 1])
        for p in policy.split(','):
            for f in AUGMENT_FNS[p]:
                x = f(x)
        if channels_first:
            x = tf.transpose(x, [0, 3, 1, 2])
    return x


def rand_brightness(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) - 0.5
    x = x + magnitude
    return x


def rand_saturation(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) * 2
    x_mean = tf.reduce_mean(x, axis=3, keepdims=True)
    x = (x - x_mean) * magnitude + x_mean
    return x


def rand_contrast(x):
    magnitude = tf.random.uniform([tf.shape(x)[0], 1, 1, 1]) + 0.5
    x_mean = tf.reduce_mean(x, axis=[1, 2, 3], keepdims=True)
    x = (x - x_mean) * magnitude + x_mean
    return x


def rand_translation(x, ratio=0.125):
    batch_size = tf.shape(x)[0]
    image_size = tf.shape(x)[1:3]
    shift = tf.cast(tf.cast(image_size, tf.float32) * ratio + 0.5, tf.int32)
    translation_x = tf.random.uniform([batch_size, 1], -shift[0], shift[0] + 1, dtype=tf.int32)
    translation_y = tf.random.uniform([batch_size, 1], -shift[1], shift[1] + 1, dtype=tf.int32)
    grid_x = tf.clip_by_value(tf.expand_dims(tf.range(image_size[0], dtype=tf.int32), 0) + translation_x + 1, 0, image_size[0] + 1)
    grid_y = tf.clip_by_value(tf.expand_dims(tf.range(image_size[1], dtype=tf.int32), 0) + translation_y + 1, 0, image_size[1] + 1)
    x = tf.gather_nd(tf.pad(x, [[0, 0], [1, 1], [0, 0], [0, 0]]), tf.expand_dims(grid_x, -1), batch_dims=1)
    x = tf.transpose(tf.gather_nd(tf.pad(tf.transpose(x, [0, 2, 1, 3]), [[0, 0], [1, 1], [0, 0], [0, 0]]), tf.expand_dims(grid_y, -1), batch_dims=1), [0, 2, 1, 3])
    return x


def rand_cutout(x, ratio=0.5):
    batch_size = tf.shape(x)[0]
    image_size = tf.shape(x)[1:3]
    cutout_size = tf.cast(tf.cast(image_size, tf.float32) * ratio + 0.5, tf.int32)
    offset_x = tf.random.uniform([tf.shape(x)[0], 1, 1], maxval=image_size[0] + (1 - cutout_size[0] % 2), dtype=tf.int32)
    offset_y = tf.random.uniform([tf.shape(x)[0], 1, 1], maxval=image_size[1] + (1 - cutout_size[1] % 2), dtype=tf.int32)
    grid_batch, grid_x, grid_y = tf.meshgrid(tf.range(batch_size, dtype=tf.int32), tf.range(cutout_size[0], dtype=tf.int32), tf.range(cutout_size[1], dtype=tf.int32), indexing='ij')
    cutout_grid = tf.stack([grid_batch, grid_x + offset_x - cutout_size[0] // 2, grid_y + offset_y - cutout_size[1] // 2], axis=-1)
    mask_shape = tf.stack([batch_size, image_size[0], image_size[1]])
    cutout_grid = tf.maximum(cutout_grid, 0)
    cutout_grid = tf.minimum(cutout_grid, tf.reshape(mask_shape - 1, [1, 1, 1, 3]))
    mask = tf.maximum(1 - tf.scatter_nd(cutout_grid, tf.ones([batch_size, cutout_size[0], cutout_size[1]], dtype=tf.float32), mask_shape), 0)
    x = x * tf.expand_dims(mask, axis=3)
    return x


AUGMENT_FNS = {
    'color': [rand_brightness, rand_saturation, rand_contrast],
    'translation': [rand_translation],
    'cutout': [rand_cutout],
}

def aug_fn(image):
        return DiffAugment(image,"translation,cutout")

# %%
both_images = tf.concat([example_monet, example_photo], axis=0)       
aug_images = aug_fn(both_images)
aug_monet, aug_photo = tf.split(aug_images, num_or_size_splits=2, axis=0)

# %%
plt.subplot(121)
plt.title('Photo')
plt.imshow(aug_photo[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Monet')
plt.imshow(aug_monet[0] * 0.5 + 0.5)

# %% [markdown]
# ## ResNet Generator

# %%
def Downsample(X, filter_count, kernel_size, padding, stride, apply_norm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
    
    X = tf.keras.layers.ZeroPadding2D((padding,padding))(X)
    X = tf.keras.layers.Conv2D(filter_count, (kernel_size,kernel_size), padding='valid', strides=(stride,stride), 
                                      kernel_initializer=initializer, use_bias=False)(X)
    
    if apply_norm:
        X = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(X)
    
    X = tf.keras.layers.LeakyReLU()(X)
    
    return X

# %%
def Upsample(X, filter_count, kernel_size, stride, activation='relu', apply_norm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    X = tf.keras.layers.Conv2DTranspose(filter_count, (kernel_size,kernel_size), padding='same', strides=(stride,stride), 
                                        kernel_initializer=initializer, use_bias=False)(X)
    
    if apply_norm:
        X = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(X)
        
    X = tf.keras.layers.Activation(activation)(X)
    
    return X

# %%
def ResidualBlock(X):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
    
    X_shortcut = X
    
    # Layer 1   
    X = tf.keras.layers.ZeroPadding2D((1,1))(X)
    X = tf.keras.layers.Conv2D(256, (3,3), padding='valid', strides=(1,1), kernel_initializer=initializer, use_bias=False)(X)
    X = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(X)
    X = tf.keras.layers.Activation('relu')(X)
    
    # Layer 2  
    X = tf.keras.layers.ZeroPadding2D((1,1))(X)
    X = tf.keras.layers.Conv2D(256, (3,3), padding='valid', strides=(1,1), kernel_initializer=initializer, use_bias=False)(X)
    X = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(X)
    
    X = tf.keras.layers.Add()([X, X_shortcut])
    X = tf.keras.layers.Activation('relu')(X)
    
    return X

# %%
def ResNetGenerator(height=SIZE, width=SIZE):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
    
    X_input = tf.keras.layers.Input((height, width, 3))
    
    skips = []
    
    X = Downsample(X_input, 64, 7, 3, 1, apply_norm=False)
    skips.append(X)
    
    X = Downsample(X, 128, 3, 1, 2)
    skips.append(X)
    
    X = Downsample(X, 256, 3, 1, 2)
    
    X = ResidualBlock(X)
    X = ResidualBlock(X)
    X = ResidualBlock(X)
    X = ResidualBlock(X)
    X = ResidualBlock(X)
    X = ResidualBlock(X)
    #X = ResidualBlock(X)
    #X = ResidualBlock(X)
    #X = ResidualBlock(X)
    
    skips = list(reversed(skips))
        
    X = Upsample(X, 128, 4, 2)
    X = tf.keras.layers.Concatenate()([X, skips[0]])
    
    X = Upsample(X, 64, 4, 2)
    X = tf.keras.layers.Concatenate()([X, skips[1]])
    
    X = Upsample(X, 3, 7, 1, activation='tanh', apply_norm=False)
    
    model = tf.keras.models.Model(inputs=X_input, outputs=X)

    return model

# %%
generator = ResNetGenerator()
generator.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 258, 258, 64) 0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 128 73728       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization (Instanc (None, 128, 128, 128 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 128, 128, 128 0           instance_normalization[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 130, 130, 128 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 256)  294912      zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_1 (Insta (None, 64, 64, 256)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 256)  0           instance_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 66, 66, 256)  0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 256)  589824      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_2 (Insta (None, 64, 64, 256)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 256)  0           instance_normalization_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 66, 66, 256)  0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  589824      zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_3 (Insta (None, 64, 64, 256)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 256)  0           instance_normalization_3[0][0]
#                                                                  leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 66, 66, 256)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  589824      zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# instance_normalization_4 (Insta (None, 64, 64, 256)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 256)  0           instance_normalization_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 66, 66, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  589824      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# instance_normalization_5 (Insta (None, 64, 64, 256)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 256)  0           instance_normalization_5[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 66, 66, 256)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  589824      zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# instance_normalization_6 (Insta (None, 64, 64, 256)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 256)  0           instance_normalization_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 66, 66, 256)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  589824      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# instance_normalization_7 (Insta (None, 64, 64, 256)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           instance_normalization_7[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 66, 66, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 256)  589824      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# instance_normalization_8 (Insta (None, 64, 64, 256)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 66, 66, 256)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 256)  589824      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# instance_normalization_9 (Insta (None, 64, 64, 256)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 256)  0           instance_normalization_9[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 66, 66, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  589824      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# instance_normalization_10 (Inst (None, 64, 64, 256)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 256)  0           instance_normalization_10[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 66, 66, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  589824      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# instance_normalization_11 (Inst (None, 64, 64, 256)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 256)  0           instance_normalization_11[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 66, 66, 256)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  589824      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# instance_normalization_12 (Inst (None, 64, 64, 256)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 256)  0           instance_normalization_12[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 66, 66, 256)  0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  589824      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# instance_normalization_13 (Inst (None, 64, 64, 256)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 256)  0           instance_normalization_13[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 128, 128, 128 524288      activation_11[0][0]
# __________________________________________________________________________________________________
# instance_normalization_14 (Inst (None, 128, 128, 128 256         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 128, 128, 128 0           instance_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 128, 256 0           activation_12[0][0]
#                                                                  leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 256, 64) 262144      concatenate[0][0]
# __________________________________________________________________________________________________
# instance_normalization_15 (Inst (None, 256, 256, 64) 128         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 256, 256, 64) 0           instance_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 128 0           activation_13[0][0]
#                                                                  leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 3)  18816       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 256, 256, 3)  0           conv2d_transpose_2[0][0]
# ==================================================================================================
# Total params: 8,268,480
# Trainable params: 8,268,480
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## PatchGAN Discriminator

# %%
def Discriminator(height=SIZE, width=SIZE):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
    
    X_input = tf.keras.layers.Input((height, width, 3))

    X = Downsample(X_input, 64, 4, 1, 2, apply_norm=False)
    X = Downsample(X, 128, 4, 1, 2)
    X = Downsample(X, 256, 4, 1, 2)
    X = Downsample(X, 512, 4, 1, 1)
    
    X = tf.keras.layers.ZeroPadding2D()(X)
    X = tf.keras.layers.Conv2D(1, (4,4), padding='valid', strides=(1,1), kernel_initializer=initializer, use_bias=False)(X)   
    X = tf.keras.layers.Activation('sigmoid')(X)
    
    model = tf.keras.models.Model(inputs=X_input, outputs=X)

    return model

# %%
discriminator = Discriminator()
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# zero_padding2d_15 (ZeroPaddi (None, 258, 258, 3)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 128, 128, 64)      3072
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# zero_padding2d_16 (ZeroPaddi (None, 130, 130, 64)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 64, 64, 128)       131072
# _________________________________________________________________
# instance_normalization_16 (I (None, 64, 64, 128)       256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# zero_padding2d_17 (ZeroPaddi (None, 66, 66, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 32, 256)       524288
# _________________________________________________________________
# instance_normalization_17 (I (None, 32, 32, 256)       512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# zero_padding2d_18 (ZeroPaddi (None, 34, 34, 256)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 31, 31, 512)       2097152
# _________________________________________________________________
# instance_normalization_18 (I (None, 31, 31, 512)       1024
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 31, 31, 512)       0
# _________________________________________________________________
# zero_padding2d_19 (ZeroPaddi (None, 33, 33, 512)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 30, 30, 1)         8192
# _________________________________________________________________
# activation_15 (Activation)   (None, 30, 30, 1)         0
# =================================================================
# Total params: 2,765,568
# Trainable params: 2,765,568
# Non-trainable params: 0
# _________________________________________________________________

# %%
with strategy.scope():
    monet_generator = ResNetGenerator(height=None, width=None) # transforms photos to Monet-esque paintings
    photo_generator = ResNetGenerator(height=None, width=None) # transforms Monet paintings to be more like photos

    monet_discriminator = Discriminator(height=None, width=None) # differentiates real Monet paintings and generated Monet paintings
    photo_discriminator = Discriminator(height=None, width=None) # differentiates real photos and generated photos

# %%
to_monet = monet_generator(example_photo)

plt.subplot(1, 2, 1)
plt.title("Original Photo")
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(1, 2, 2)
plt.title("Monet-esque Photo")
plt.imshow(to_monet[0] * 0.5 + 0.5)
plt.show()

# %% [markdown]
# ## Training

# %%
class CycleGan(keras.Model):
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn
        
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
        
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # Diff Augmentation Start
            both_monet = tf.concat([real_monet, fake_monet], axis=0)      
            both_photo = tf.concat([real_photo, fake_photo], axis=0)            
            
            aug_monet = aug_fn(both_monet)
            aug_photo = aug_fn(both_photo)
            
            aug_real_monet, aug_fake_monet = tf.split(aug_monet, num_or_size_splits=2, axis=0)
            aug_real_photo, aug_fake_photo = tf.split(aug_photo, num_or_size_splits=2, axis=0)
            # Diff Augmentation End
            
            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(aug_real_monet, training=True)
            disc_real_photo = self.p_disc(aug_real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(aug_fake_monet, training=True)
            disc_fake_photo = self.p_disc(aug_fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)

        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %%
with strategy.scope():
    def discriminator_loss(real, generated):
        real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=False, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

        generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=False, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)

        total_disc_loss = real_loss + generated_loss

        return total_disc_loss * 0.5

# %%
with strategy.scope():
    def generator_loss(generated):
        return tf.keras.losses.BinaryCrossentropy(from_logits=False, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated), generated)

# %%
with strategy.scope():
    def calc_cycle_loss(real_image, cycled_image, LAMBDA):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

        return LAMBDA * loss1

# %%
with strategy.scope():
    def identity_loss(real_image, same_image, LAMBDA):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %%
@tf.function
def linear_schedule_with_warmup(step):
    """ Create a schedule with a learning rate that decreases linearly after
    linearly increasing during a warmup period.
    """
    lr_start   = 2e-4
    lr_max     = 2e-4
    lr_min     = 0.
    
    steps_per_epoch = int(max(n_monet_samples, n_photo_samples)//BATCH_SIZE)
    total_steps = EPOCHS * steps_per_epoch
    warmup_steps = 1
    hold_max_steps = total_steps * 0.8
    
    if step < warmup_steps:
        lr = (lr_max - lr_start) / warmup_steps * step + lr_start
    elif step < warmup_steps + hold_max_steps:
        lr = lr_max
    else:
        lr = lr_max * ((total_steps - step) / (total_steps - warmup_steps - hold_max_steps))
        if lr_min is not None:
            lr = tf.math.maximum(lr_min, lr)

    return lr

# %%
with strategy.scope():
    
    lr_monet_gen = lambda: linear_schedule_with_warmup(tf.cast(monet_generator_optimizer.iterations, tf.float32))
    lr_photo_gen = lambda: linear_schedule_with_warmup(tf.cast(photo_generator_optimizer.iterations, tf.float32))
    
    monet_generator_optimizer = tf.keras.optimizers.Adam(learning_rate=lr_monet_gen, beta_1=0.5)
    photo_generator_optimizer = tf.keras.optimizers.Adam(learning_rate=lr_photo_gen, beta_1=0.5)

    lr_monet_disc = lambda: linear_schedule_with_warmup(tf.cast(monet_discriminator_optimizer.iterations, tf.float32))
    lr_photo_disc = lambda: linear_schedule_with_warmup(tf.cast(photo_discriminator_optimizer.iterations, tf.float32))
    
    monet_discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=lr_monet_disc, beta_1=0.5)
    photo_discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=lr_photo_disc, beta_1=0.5)

# %%
with strategy.scope():
    cycle_gan_model = CycleGan(
        monet_generator, photo_generator, monet_discriminator, photo_discriminator
    )

    cycle_gan_model.compile(
        m_gen_optimizer = monet_generator_optimizer,
        p_gen_optimizer = photo_generator_optimizer,
        m_disc_optimizer = monet_discriminator_optimizer,
        p_disc_optimizer = photo_discriminator_optimizer,
        gen_loss_fn = generator_loss,
        disc_loss_fn = discriminator_loss,
        cycle_loss_fn = calc_cycle_loss,
        identity_loss_fn = identity_loss
    )

# %%
history = cycle_gan_model.fit(tf.data.Dataset.zip((monet_ds, photo_ds)), 
                        epochs=EPOCHS, 
                        steps_per_epoch=max(n_monet_samples, n_photo_samples)//BATCH_SIZE).history
# Out:
# Epoch 1/100
# 439/439 [==============================] - 220s 164ms/step - monet_gen_loss: 3.0362 - photo_gen_loss: 3.1270 - monet_disc_loss: 0.6675 - photo_disc_loss: 0.6528
# Epoch 2/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 2.2378 - photo_gen_loss: 2.2631 - monet_disc_loss: 0.6408 - photo_disc_loss: 0.6475
# Epoch 3/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 2.1174 - photo_gen_loss: 2.1494 - monet_disc_loss: 0.6395 - photo_disc_loss: 0.6404
# Epoch 4/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 2.0506 - photo_gen_loss: 2.0719 - monet_disc_loss: 0.6255 - photo_disc_loss: 0.6260
# Epoch 5/100
# 439/439 [==============================] - 72s 164ms/step - monet_gen_loss: 1.9711 - photo_gen_loss: 2.0395 - monet_disc_loss: 0.6296 - photo_disc_loss: 0.6256
# Epoch 6/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.9105 - photo_gen_loss: 2.0011 - monet_disc_loss: 0.6427 - photo_disc_loss: 0.6343
# Epoch 7/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.8677 - photo_gen_loss: 1.9824 - monet_disc_loss: 0.6541 - photo_disc_loss: 0.6244
# Epoch 8/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.8121 - photo_gen_loss: 1.9515 - monet_disc_loss: 0.6604 - photo_disc_loss: 0.6336
# Epoch 9/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.8145 - photo_gen_loss: 1.9148 - monet_disc_loss: 0.6666 - photo_disc_loss: 0.6423
# Epoch 10/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7709 - photo_gen_loss: 1.8724 - monet_disc_loss: 0.6796 - photo_disc_loss: 0.6559
# Epoch 11/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7857 - photo_gen_loss: 1.8428 - monet_disc_loss: 0.6700 - photo_disc_loss: 0.6646
# Epoch 12/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.8380 - photo_gen_loss: 1.8793 - monet_disc_loss: 0.6616 - photo_disc_loss: 0.6580
# Epoch 13/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7613 - photo_gen_loss: 1.8165 - monet_disc_loss: 0.6673 - photo_disc_loss: 0.6557
# Epoch 14/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7513 - photo_gen_loss: 1.8258 - monet_disc_loss: 0.6698 - photo_disc_loss: 0.6589
# Epoch 15/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7726 - photo_gen_loss: 1.8390 - monet_disc_loss: 0.6676 - photo_disc_loss: 0.6488
# Epoch 16/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7776 - photo_gen_loss: 1.8470 - monet_disc_loss: 0.6706 - photo_disc_loss: 0.6463
# Epoch 17/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7891 - photo_gen_loss: 1.8474 - monet_disc_loss: 0.6553 - photo_disc_loss: 0.6493
# Epoch 18/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7522 - photo_gen_loss: 1.7965 - monet_disc_loss: 0.6628 - photo_disc_loss: 0.6580
# Epoch 19/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.8265 - photo_gen_loss: 1.9118 - monet_disc_loss: 0.6612 - photo_disc_loss: 0.6414
# Epoch 20/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7611 - photo_gen_loss: 1.8569 - monet_disc_loss: 0.6693 - photo_disc_loss: 0.6451
# Epoch 21/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7317 - photo_gen_loss: 1.7944 - monet_disc_loss: 0.6619 - photo_disc_loss: 0.6486
# Epoch 22/100
# 439/439 [==============================] - 72s 164ms/step - monet_gen_loss: 1.7514 - photo_gen_loss: 1.8279 - monet_disc_loss: 0.6600 - photo_disc_loss: 0.6467
# Epoch 23/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7324 - photo_gen_loss: 1.8151 - monet_disc_loss: 0.6661 - photo_disc_loss: 0.6457
# Epoch 24/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7559 - photo_gen_loss: 1.8336 - monet_disc_loss: 0.6687 - photo_disc_loss: 0.6358
# Epoch 25/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7192 - photo_gen_loss: 1.7677 - monet_disc_loss: 0.6627 - photo_disc_loss: 0.6546
# Epoch 26/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7120 - photo_gen_loss: 1.7417 - monet_disc_loss: 0.6644 - photo_disc_loss: 0.6600
# Epoch 27/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6800 - photo_gen_loss: 1.7904 - monet_disc_loss: 0.6677 - photo_disc_loss: 0.6470
# Epoch 28/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6676 - photo_gen_loss: 1.7417 - monet_disc_loss: 0.6669 - photo_disc_loss: 0.6580
# Epoch 29/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7433 - photo_gen_loss: 1.7883 - monet_disc_loss: 0.6567 - photo_disc_loss: 0.6478
# Epoch 30/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6427 - photo_gen_loss: 1.7051 - monet_disc_loss: 0.6658 - photo_disc_loss: 0.6526
# Epoch 31/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6635 - photo_gen_loss: 1.6977 - monet_disc_loss: 0.6695 - photo_disc_loss: 0.6631
# Epoch 32/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7362 - photo_gen_loss: 1.8315 - monet_disc_loss: 0.6694 - photo_disc_loss: 0.6399
# Epoch 33/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6887 - photo_gen_loss: 1.7269 - monet_disc_loss: 0.6626 - photo_disc_loss: 0.6528
# Epoch 34/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.8800 - photo_gen_loss: 1.8797 - monet_disc_loss: 0.6613 - photo_disc_loss: 0.6500
# Epoch 35/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.8577 - photo_gen_loss: 1.8806 - monet_disc_loss: 0.6515 - photo_disc_loss: 0.6475
# Epoch 36/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7068 - photo_gen_loss: 1.7795 - monet_disc_loss: 0.6638 - photo_disc_loss: 0.6383
# Epoch 37/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6555 - photo_gen_loss: 1.7443 - monet_disc_loss: 0.6706 - photo_disc_loss: 0.6502
# Epoch 38/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6325 - photo_gen_loss: 1.6608 - monet_disc_loss: 0.6666 - photo_disc_loss: 0.6629
# Epoch 39/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6074 - photo_gen_loss: 1.6633 - monet_disc_loss: 0.6646 - photo_disc_loss: 0.6517
# Epoch 40/100
# 439/439 [==============================] - 72s 164ms/step - monet_gen_loss: 1.5953 - photo_gen_loss: 1.6452 - monet_disc_loss: 0.6681 - photo_disc_loss: 0.6551
# Epoch 41/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5972 - photo_gen_loss: 1.6428 - monet_disc_loss: 0.6700 - photo_disc_loss: 0.6554
# Epoch 42/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6390 - photo_gen_loss: 1.6576 - monet_disc_loss: 0.6633 - photo_disc_loss: 0.6570
# Epoch 43/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6505 - photo_gen_loss: 1.6887 - monet_disc_loss: 0.6679 - photo_disc_loss: 0.6537
# Epoch 44/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6295 - photo_gen_loss: 1.6526 - monet_disc_loss: 0.6627 - photo_disc_loss: 0.6554
# Epoch 45/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6449 - photo_gen_loss: 1.6733 - monet_disc_loss: 0.6543 - photo_disc_loss: 0.6472
# Epoch 46/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6323 - photo_gen_loss: 1.6516 - monet_disc_loss: 0.6621 - photo_disc_loss: 0.6534
# Epoch 47/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6432 - photo_gen_loss: 1.6411 - monet_disc_loss: 0.6489 - photo_disc_loss: 0.6524
# Epoch 48/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7350 - photo_gen_loss: 1.7442 - monet_disc_loss: 0.6411 - photo_disc_loss: 0.6510
# Epoch 49/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7007 - photo_gen_loss: 1.7206 - monet_disc_loss: 0.6532 - photo_disc_loss: 0.6512
# Epoch 50/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6385 - photo_gen_loss: 1.6972 - monet_disc_loss: 0.6633 - photo_disc_loss: 0.6531
# Epoch 51/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6124 - photo_gen_loss: 1.6510 - monet_disc_loss: 0.6567 - photo_disc_loss: 0.6540
# Epoch 52/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6035 - photo_gen_loss: 1.6167 - monet_disc_loss: 0.6599 - photo_disc_loss: 0.6625
# Epoch 53/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.7854 - photo_gen_loss: 1.8262 - monet_disc_loss: 0.6516 - photo_disc_loss: 0.6339
# Epoch 54/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5926 - photo_gen_loss: 1.6371 - monet_disc_loss: 0.6689 - photo_disc_loss: 0.6516
# Epoch 55/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5860 - photo_gen_loss: 1.6323 - monet_disc_loss: 0.6557 - photo_disc_loss: 0.6416
# Epoch 56/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5994 - photo_gen_loss: 1.6247 - monet_disc_loss: 0.6638 - photo_disc_loss: 0.6626
# Epoch 57/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5605 - photo_gen_loss: 1.6020 - monet_disc_loss: 0.6696 - photo_disc_loss: 0.6598
# Epoch 58/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5763 - photo_gen_loss: 1.6077 - monet_disc_loss: 0.6601 - photo_disc_loss: 0.6508
# Epoch 59/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5730 - photo_gen_loss: 1.6378 - monet_disc_loss: 0.6645 - photo_disc_loss: 0.6613
# Epoch 60/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6221 - photo_gen_loss: 1.7096 - monet_disc_loss: 0.6540 - photo_disc_loss: 0.6316
# Epoch 61/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5740 - photo_gen_loss: 1.6031 - monet_disc_loss: 0.6538 - photo_disc_loss: 0.6508
# Epoch 62/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5550 - photo_gen_loss: 1.5712 - monet_disc_loss: 0.6627 - photo_disc_loss: 0.6646
# Epoch 63/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5429 - photo_gen_loss: 1.5794 - monet_disc_loss: 0.6659 - photo_disc_loss: 0.6578
# Epoch 64/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6196 - photo_gen_loss: 1.6228 - monet_disc_loss: 0.6517 - photo_disc_loss: 0.6534
# Epoch 65/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5905 - photo_gen_loss: 1.6167 - monet_disc_loss: 0.6544 - photo_disc_loss: 0.6552
# Epoch 66/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5904 - photo_gen_loss: 1.6046 - monet_disc_loss: 0.6573 - photo_disc_loss: 0.6564
# Epoch 67/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5446 - photo_gen_loss: 1.5769 - monet_disc_loss: 0.6606 - photo_disc_loss: 0.6546
# Epoch 68/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5478 - photo_gen_loss: 1.5671 - monet_disc_loss: 0.6636 - photo_disc_loss: 0.6593
# Epoch 69/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5864 - photo_gen_loss: 1.5904 - monet_disc_loss: 0.6581 - photo_disc_loss: 0.6560
# Epoch 70/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5661 - photo_gen_loss: 1.5788 - monet_disc_loss: 0.6571 - photo_disc_loss: 0.6580
# Epoch 71/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5624 - photo_gen_loss: 1.5654 - monet_disc_loss: 0.6565 - photo_disc_loss: 0.6561
# Epoch 72/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.6236 - photo_gen_loss: 1.6348 - monet_disc_loss: 0.6586 - photo_disc_loss: 0.6513
# Epoch 73/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5353 - photo_gen_loss: 1.5544 - monet_disc_loss: 0.6625 - photo_disc_loss: 0.6564
# Epoch 74/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5561 - photo_gen_loss: 1.5784 - monet_disc_loss: 0.6625 - photo_disc_loss: 0.6573
# Epoch 75/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5498 - photo_gen_loss: 1.5607 - monet_disc_loss: 0.6585 - photo_disc_loss: 0.6526
# Epoch 76/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5728 - photo_gen_loss: 1.5791 - monet_disc_loss: 0.6539 - photo_disc_loss: 0.6485
# Epoch 77/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5556 - photo_gen_loss: 1.5761 - monet_disc_loss: 0.6593 - photo_disc_loss: 0.6447
# Epoch 78/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5481 - photo_gen_loss: 1.5567 - monet_disc_loss: 0.6632 - photo_disc_loss: 0.6557
# Epoch 79/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5625 - photo_gen_loss: 1.5894 - monet_disc_loss: 0.6585 - photo_disc_loss: 0.6577
# Epoch 80/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5421 - photo_gen_loss: 1.5586 - monet_disc_loss: 0.6620 - photo_disc_loss: 0.6601
# Epoch 81/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5600 - photo_gen_loss: 1.5518 - monet_disc_loss: 0.6571 - photo_disc_loss: 0.6563
# Epoch 82/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5329 - photo_gen_loss: 1.5405 - monet_disc_loss: 0.6578 - photo_disc_loss: 0.6543
# Epoch 83/100
# 439/439 [==============================] - 72s 165ms/step - monet_gen_loss: 1.5444 - photo_gen_loss: 1.5364 - monet_disc_loss: 0.6543 - photo_disc_loss: 0.6538
# Epoch 84/100
# 439/439 [==============================] - 73s 166ms/step - monet_gen_loss: 1.5443 - photo_gen_loss: 1.5480 - monet_disc_loss: 0.6485 - photo_disc_loss: 0.6518
# Epoch 85/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5117 - photo_gen_loss: 1.5100 - monet_disc_loss: 0.6524 - photo_disc_loss: 0.6595
# Epoch 86/100
# 439/439 [==============================] - 73s 167ms/step - monet_gen_loss: 1.4998 - photo_gen_loss: 1.5039 - monet_disc_loss: 0.6560 - photo_disc_loss: 0.6494
# Epoch 87/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5018 - photo_gen_loss: 1.5212 - monet_disc_loss: 0.6558 - photo_disc_loss: 0.6471
# Epoch 88/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.5006 - photo_gen_loss: 1.5073 - monet_disc_loss: 0.6513 - photo_disc_loss: 0.6408
# Epoch 89/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4925 - photo_gen_loss: 1.4863 - monet_disc_loss: 0.6492 - photo_disc_loss: 0.6499
# Epoch 90/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4828 - photo_gen_loss: 1.4912 - monet_disc_loss: 0.6490 - photo_disc_loss: 0.6461
# Epoch 91/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4921 - photo_gen_loss: 1.4876 - monet_disc_loss: 0.6491 - photo_disc_loss: 0.6492
# Epoch 92/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4550 - photo_gen_loss: 1.4799 - monet_disc_loss: 0.6494 - photo_disc_loss: 0.6476
# Epoch 93/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4552 - photo_gen_loss: 1.4611 - monet_disc_loss: 0.6512 - photo_disc_loss: 0.6516
# Epoch 94/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4784 - photo_gen_loss: 1.4733 - monet_disc_loss: 0.6441 - photo_disc_loss: 0.6484
# Epoch 95/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4590 - photo_gen_loss: 1.4550 - monet_disc_loss: 0.6385 - photo_disc_loss: 0.6422
# Epoch 96/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4606 - photo_gen_loss: 1.4554 - monet_disc_loss: 0.6392 - photo_disc_loss: 0.6448
# Epoch 97/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4601 - photo_gen_loss: 1.4705 - monet_disc_loss: 0.6446 - photo_disc_loss: 0.6405
# Epoch 98/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4517 - photo_gen_loss: 1.4533 - monet_disc_loss: 0.6423 - photo_disc_loss: 0.6453
# Epoch 99/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4521 - photo_gen_loss: 1.4625 - monet_disc_loss: 0.6407 - photo_disc_loss: 0.6432
# Epoch 100/100
# 439/439 [==============================] - 73s 165ms/step - monet_gen_loss: 1.4697 - photo_gen_loss: 1.4660 - monet_disc_loss: 0.6353 - photo_disc_loss: 0.6340

# %%
loss_results_df = pd.DataFrame(history)
loss_results_df = loss_results_df.applymap(np.mean)

# %%
plt.plot(loss_results_df.index, loss_results_df['monet_gen_loss'], color='g', label='Loss Monet Generator')
plt.plot(loss_results_df.index, loss_results_df['photo_gen_loss'], color='r', label='Loss Photo Generator')
plt.plot(loss_results_df.index, loss_results_df['monet_disc_loss'], color='b', label='Loss Monet Discriminator')
plt.plot(loss_results_df.index, loss_results_df['photo_disc_loss'], color='m', label='Loss Photo Discriminator')
plt.legend(loc='best')
plt.show()

# %%
_, ax = plt.subplots(5, 2, figsize=(12, 12))
for i, img in enumerate(photo_ds_test.take(5)):
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    
    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()
# Out:
# 2022-06-01 17:00:31.367306: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 409566, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1654102831.363324372","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 409566, Output num: 0","grpc_status":3}

# %% [markdown]
# ## Prediction and Submission

# %%
import PIL
! mkdir ../images

# %%
i = 1
for img in photo_ds_test:
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    im = PIL.Image.fromarray(prediction)
    im.save("../images/" + str(i) + ".jpg")
    i += 1
# Out:
# 2022-06-01 17:43:47.837949: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 5364327, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1654105427.837805194","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 5364327, Output num: 0","grpc_status":3}

# %%
import shutil
shutil.make_archive("/kaggle/working/images", 'zip', "/kaggle/images")
# Out:
# '/kaggle/working/images.zip'
